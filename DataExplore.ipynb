# %%
import glob
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image
import csv
import cv2

# %matplotlib inline

# %%
imlist = glob.glob('/Users/Admin/Desktop/vehicle/**/*.jpg', recursive = True)

# %%
c = 0

for i in imlist:
    c += 1
    img = Image.open(i)
    string = "/Users/Admin/Desktop/vehicle/" + str(c) + ".png"
    img.save(string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Miniconda3\envs\carnd-term1\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     463     try:
# --> 464         fh = fp.fileno()
#     465         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7b6b07043d97> in <module>()
#       5     img = Image.open(i)
#       6     string = "/Users/Admin/Desktop/vehicle/" + str(c) + ".png"
# ----> 7     img.save(string)
#
# ~\Miniconda3\envs\carnd-term1\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1891
#    1892         try:
# -> 1893             save_handler(self, fp, filename)
#    1894         finally:
#    1895             # do what we can to clean up
#
# ~\Miniconda3\envs\carnd-term1\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, check)
#     794
#     795     ImageFile._save(im, _idat(fp, chunk),
# --> 796                     [("zip", (0, 0)+im.size, 0, rawmode)])
#     797
#     798     chunk(fp, b"IEND", b"")
#
# ~\Miniconda3\envs\carnd-term1\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     476             else:
#     477                 while True:
# --> 478                     l, s, d = e.encode(bufsize)
#     479                     fp.write(d)
#     480                     if s:
#
# KeyboardInterrupt:

# %%
with open('/Users/Admin/Desktop/vehicle/labels.csv', 'r') as f:
    reader = csv.reader(f)
    csvdata = list(reader)
    
xmin = csvdata[1][0]
xmax = csvdata[1][1]
ymin = csvdata[1][2]
ymax = csvdata[1][3]

print(xmin)
print(ymin)
print(xmax)
print(ymax)
# Out:
# 785
# 905
# 533
# 644

# %%
something = mpimg.imread(imlist[0])
plt.imshow(something)

# %%
cv2.draw_rect
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-20276185f686> in <module>()
#       1 imtest = Image.open(imlist[0])
# ----> 2 crop = imtest[100:300,100:300]
#       3 plt.imshow(imtest2)
#
# TypeError: 'JpegImageFile' object is not subscriptable
